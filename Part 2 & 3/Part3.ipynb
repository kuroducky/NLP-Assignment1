# %%
pip install vadersentiment
# Out:
# Collecting vadersentiment
#   Downloading https://files.pythonhosted.org/packages/76/fc/310e16254683c1ed35eeb97386986d6c00bc29df17ce280aed64d55537e9/vaderSentiment-3.3.2-py2.py3-none-any.whl (125kB)
#      |████████████████████████████████| 133kB 1.5MB/s eta 0:00:01
# Requirement already satisfied: requests in /Users/lestertay/opt/anaconda3/lib/python3.7/site-packages (from vadersentiment) (2.22.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/lestertay/opt/anaconda3/lib/python3.7/site-packages (from requests->vadersentiment) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/lestertay/opt/anaconda3/lib/python3.7/site-packages (from requests->vadersentiment) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lestertay/opt/anaconda3/lib/python3.7/site-packages (from requests->vadersentiment) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/lestertay/opt/anaconda3/lib/python3.7/site-packages (from requests->vadersentiment) (3.0.4)
# Installing collected packages: vadersentiment
# Successfully installed vadersentiment-3.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import re
import textblob
from textblob import TextBlob
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
def extract_lines(filename):
    lines = []
    started = False
    with open(filename, 'r') as f:
        for line in f.readlines():
            if line[0] == '<':
                started = True
                tmp = ''
            
            if started:
                tmp += line
                if line[len(line) - 2] == '>':
                    lines.append(tmp)
                    started = False
        
    return lines

# %%
lines = extract_lines('Reviews.txt')
df = pd.DataFrame(lines, columns=['Lines'])

# %%
def cleanText(text):
    text = re.sub(r'<', '', text)
    text = re.sub(r'>', '', text)
    text = re.sub('\n', ' ', text)
    return text

# %%
analyzer = SentimentIntensityAnalyzer()
def makeSentiment(type):
    def sentiment(text):
        return analyzer.polarity_scores(text)[type]
    return sentiment
    
def classify(compound):
    if compound >= 0.5:
        return 'Positive'
    elif compound >= -0.4 and compound < 0.5:
        return 'Neutral'
    else:
        return 'Negative'

# %%
df['Lines'] = df['Lines'].apply(cleanText)
df['Negative'] = df['Lines'].apply(makeSentiment('neg'))
df['Positive'] = df['Lines'].apply(makeSentiment('pos'))
df['Neutral'] = df['Lines'].apply(makeSentiment('neu'))
df['Compound'] = df['Lines'].apply(makeSentiment('compound'))
df['Classify'] = df['Compound'].apply(classify)

# %%
df
# Out:
#                                                 Lines  Compound  Negative  \
# 0   1. Close to the city 2. Room is comfortable an...    0.8360     0.000
# 1   Room very spacious, clean and comfortable. Smo...    0.8434     0.000
# 2   Nearer to all the shops and jonker walk.. conv...    0.6808     0.000
# 3      The bed is comfortable and the room was calm.     0.6808     0.000
# 4   the location is so strategic and got parking l...    0.8114     0.000
# 5   Hotel is new and clean. Secure and plentiful p...    0.7346     0.000
# 6   I like the staff, the service so nice. The hou...    0.8367     0.000
# 7             The room is well clean and comfortable     0.7964     0.000
# 8   Because of faulty air-con, the staff arranged ...   -0.0258     0.159
# 9   Great location, Nice staff and Great place to ...    0.9001     0.000
# 10            Location was good. But no breakfast...    -0.2144     0.320
# 11  stay okay without breakfast package, but parki...    0.1154     0.000
# 12  television not more channels..room you must pa...    0.0460     0.100
# 13  Iron that provided at the corner of each level...   -0.3818     0.128
# 14  Check in and check out really fast.. I like th...    0.4144     0.000
# 15  Room is clean with new cabinet Short of parkin...    0.4019     0.000
# 16  The room and cleanliness is excellent The rece...   -0.6559     0.127
# 17  i love the water pressure in the shower. Addit...    0.2928     0.125
# 18  The facilities could've been better, but overa...    0.7003     0.000
# 19  i arrived at about 3.00 pm but the room still ...    0.2926     0.075
# 20  the service was so poor..yesterday night my br...   -0.5628     0.123
# 21  Everything. The room is dirty. Not worth every...   -0.8395     0.384
# 22  Not up to expectation honestly . Rooms without...   -0.0258     0.171
# 23  Toilet door cannot lock. Air conditioning very...   -0.1770     0.121
# 24  The staff was very rude, and the room was dirty.    -0.7346     0.436
# 25  The room was noisy with children in other room...   -0.8519     0.170
# 26         Toilet was miserable. Not very functional    -0.4939     0.390
# 27                           Service is not so good.    -0.4640     0.431
# 28  The bathroom too small to hang our clothes. No...   -0.2960     0.167
#
#     Positive  Neutral  Classify
# 0      0.447    0.553  Positive
# 1      0.502    0.498  Positive
# 2      0.272    0.728  Positive
# 3      0.444    0.556  Positive
# 4      0.269    0.731  Positive
# 5      0.246    0.754  Positive
# 6      0.331    0.669  Positive
# 7      0.669    0.331  Positive
# 8      0.152    0.690   Neutral
# 9      0.647    0.353  Positive
# 10     0.223    0.457   Neutral
# 11     0.116    0.884   Neutral
# 12     0.113    0.787   Neutral
# 13     0.057    0.815   Neutral
# 14     0.165    0.835   Neutral
# 15     0.231    0.769   Neutral
# 16     0.083    0.790  Negative
# 17     0.130    0.745   Neutral
# 18     0.453    0.547  Positive
# 19     0.108    0.817   Neutral
# 20     0.030    0.848  Negative
# 21     0.000    0.616  Negative
# 22     0.166    0.663   Neutral
# 23     0.063    0.816   Neutral
# 24     0.000    0.564  Negative
# 25     0.000    0.830  Negative
# 26     0.000    0.610  Negative
# 27     0.000    0.569  Negative
# 28     0.000    0.833   Neutral

# %%
positive = df[df['Classify'] == 'Positive']
negative = df[df['Classify'] == 'Negative']
neutral = df[df['Classify'] == 'Neutral']

# %%
positive
# Out:
#                                                 Lines  Compound  Negative  \
# 0   1. Close to the city 2. Room is comfortable an...    0.8360       0.0
# 1   Room very spacious, clean and comfortable. Smo...    0.8434       0.0
# 2   Nearer to all the shops and jonker walk.. conv...    0.6808       0.0
# 3      The bed is comfortable and the room was calm.     0.6808       0.0
# 4   the location is so strategic and got parking l...    0.8114       0.0
# 5   Hotel is new and clean. Secure and plentiful p...    0.7346       0.0
# 6   I like the staff, the service so nice. The hou...    0.8367       0.0
# 7             The room is well clean and comfortable     0.7964       0.0
# 9   Great location, Nice staff and Great place to ...    0.9001       0.0
# 18  The facilities could've been better, but overa...    0.7003       0.0
#
#     Positive  Neutral  Classify
# 0      0.447    0.553  Positive
# 1      0.502    0.498  Positive
# 2      0.272    0.728  Positive
# 3      0.444    0.556  Positive
# 4      0.269    0.731  Positive
# 5      0.246    0.754  Positive
# 6      0.331    0.669  Positive
# 7      0.669    0.331  Positive
# 9      0.647    0.353  Positive
# 18     0.453    0.547  Positive

# %%
negative
# Out:
#                                                 Lines  Compound  Negative  \
# 16  The room and cleanliness is excellent The rece...   -0.6559     0.127
# 20  the service was so poor..yesterday night my br...   -0.5628     0.123
# 21  Everything. The room is dirty. Not worth every...   -0.8395     0.384
# 24  The staff was very rude, and the room was dirty.    -0.7346     0.436
# 25  The room was noisy with children in other room...   -0.8519     0.170
# 26         Toilet was miserable. Not very functional    -0.4939     0.390
# 27                           Service is not so good.    -0.4640     0.431
#
#     Positive  Neutral  Classify
# 16     0.083    0.790  Negative
# 20     0.030    0.848  Negative
# 21     0.000    0.616  Negative
# 24     0.000    0.564  Negative
# 25     0.000    0.830  Negative
# 26     0.000    0.610  Negative
# 27     0.000    0.569  Negative

# %%
neutral
# Out:
#                                                 Lines  Compound  Negative  \
# 8   Because of faulty air-con, the staff arranged ...   -0.0258     0.159
# 10            Location was good. But no breakfast...    -0.2144     0.320
# 11  stay okay without breakfast package, but parki...    0.1154     0.000
# 12  television not more channels..room you must pa...    0.0460     0.100
# 13  Iron that provided at the corner of each level...   -0.3818     0.128
# 14  Check in and check out really fast.. I like th...    0.4144     0.000
# 15  Room is clean with new cabinet Short of parkin...    0.4019     0.000
# 17  i love the water pressure in the shower. Addit...    0.2928     0.125
# 19  i arrived at about 3.00 pm but the room still ...    0.2926     0.075
# 22  Not up to expectation honestly . Rooms without...   -0.0258     0.171
# 23  Toilet door cannot lock. Air conditioning very...   -0.1770     0.121
# 28  The bathroom too small to hang our clothes. No...   -0.2960     0.167
#
#     Positive  Neutral Classify
# 8      0.152    0.690  Neutral
# 10     0.223    0.457  Neutral
# 11     0.116    0.884  Neutral
# 12     0.113    0.787  Neutral
# 13     0.057    0.815  Neutral
# 14     0.165    0.835  Neutral
# 15     0.231    0.769  Neutral
# 17     0.130    0.745  Neutral
# 19     0.108    0.817  Neutral
# 22     0.166    0.663  Neutral
# 23     0.063    0.816  Neutral
# 28     0.000    0.833  Neutral
